# %%
# %load_ext autoreload
# %autoreload 1
# %aimport my

import sys
import numpy as np
import pandas as pd
import os
import gc

import my
from my import p
import text_utils

pd.set_option("max_colwidth", 25)
pd.set_option("display.precision", 1)
pd.options.display.float_format = "{:.3f}".format

from IPython.display import HTML, display
     
dir_out = "out/"
dir_data = 'data/'
os.makedirs(dir_out, exist_ok = True)
RANDOM_STATE = 34

np.random.seed(RANDOM_STATE)
N_CPU = os.cpu_count()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Загрузка файлов с данными

# %%
train = pd.read_csv(dir_data+'train_dataset_train.csv',parse_dates=['publish_date'])
test = pd.read_csv(dir_data+'test_dataset_test.csv',parse_dates=['publish_date'])
train[:1]
# Out:
#                 document_id                     title        publish_date  \
# 0  624ac09c9a7947db3d80c...  Европейский банк разв... 2022-04-04 10:29:44
#
#                   session authors   ctr                  category  \
# 0  IDE7mtH4RBqGn-8MXfGffQ      [] 1.580  5409f11ce063da9c8b588a18
#
#                        tags  views  depth  full_reads_percent
# 0  ['55928d339a794751dc8...  20460  1.134              35.850

# %%
import ast

def str_to_list(s):
    return ast.literal_eval(s)


def encode_list_col(li, encoder, prefix=''):
    if not li:
        return f'{prefix}100000'
    return prefix + f' {prefix}'.join((np.sort(encoder.transform(li)) + 1).astype(str))

# %% [markdown]
# ### Label Encoders
#
# Fit'им энкодеры, чтобы из таких записей '55928d339a794751dc8' можно было сделать более удобные: например для тагов 't1', для авторов 'a1', для категорий просто цифры 1...9

# %%
df = pd.concat([train,test]).reset_index(drop=True)
p(df.shape)
df[:1]
# Out:
# (10000, 11)
#  ~
#                 document_id                     title        publish_date  \
# 0  624ac09c9a7947db3d80c...  Европейский банк разв... 2022-04-04 10:29:44
#
#                   session authors   ctr                  category  \
# 0  IDE7mtH4RBqGn-8MXfGffQ      [] 1.580  5409f11ce063da9c8b588a18
#
#                        tags     views  depth  full_reads_percent
# 0  ['55928d339a794751dc8... 20460.000  1.134              35.850

# %%
from sklearn.preprocessing import LabelEncoder
encoders = {}
encoders['category_enc'] = LabelEncoder().fit(df['category'])
encoders['session_enc'] = LabelEncoder().fit(df['session'])
my.save_pickle(dir_data+'encs.pcl', encoders)

# %%
df.dtypes
# Out:
# title                   object
# publish_date    datetime64[ns]
# session                 object
# authors                 object
# ctr                    float64
# category                object
# tags                    object
# dtype: object

# %%
df['authors'] = df['authors'].apply(str_to_list)
df['tags'] = df['tags'].apply(str_to_list)

# %%
all_authors = list(set(df['authors'].sum()))
all_tags = list(set(df['tags'].sum()))
len(all_authors), len(all_tags)
# Out:
# (102, 6520)

# %%
encoders['authors_enc'] = LabelEncoder().fit(all_authors)
encoders['tags_enc'] = LabelEncoder().fit(all_tags)
my.save_pickle(dir_data+'encs.pcl', encoders)

# %%
df['authors'] = df['authors'].apply(encode_list_col,args=(encoders['authors_enc'],'a'))
df['tags'] = df['tags'].apply(encode_list_col,args=(encoders['tags_enc'],'t'))
df[:3]
# Out:
#                       title        publish_date                 session  \
# 0  Европейский банк разв... 2022-04-04 10:29:44  IDE7mtH4RBqGn-8MXfGffQ
# 1  Кремль назвал регуляр... 2022-02-18 10:00:39  KtVJsteHStO5oditt3Uvzw
# 2  Госсекретарь Швеции з... 2022-02-12 04:24:02  hk7puWJwSziw0m3sfTkKWA
#
#    authors   ctr                  category                 tags
# 0  a100000 1.580  5409f11ce063da9c8b588a18  t3 t762 t3501 t3657
# 1   a6 a23 1.853  5409f11ce063da9c8b588a12      t92 t2214 t5494
# 2  a100000 0.000  5409f11ce063da9c8b588a12         t36 t91 t823

# %%
encoders['list_authors_enc'] = LabelEncoder().fit(df['authors'])
encoders['list_tags_enc'] = LabelEncoder().fit(df['tags'])
my.save_pickle(dir_data+'encs.pcl', encoders)

# %%
df['authors'].nunique(),df['tags'].nunique()
# Out:
# (633, 9468)

# %% [markdown]
# ### Точные предсказания
# Путем визуального осмотра установлено, что первые 24 символа document_id определяют часть URL страницы новости. И так как в тесте есть такие же 24 символа document_id, как и в трейне, то для нескольких новостей из теста есть дубликаты в трейне, из которых можно взять точные предсказания. Есть образцы с одинаковым путем, но разным ctr, и по ctr можно соотнести их между собой точно. Такое предположение также подтверждается полным соответствием категории, тагов, авторов, и таргетов, почти всегда одинаковый стр и похожее название, (отличаются датой публикации), если мы посмотрим только на дубликаты среди трейна.
# Сделаем таблицу для новостей из теста, имеющих дубликаты в трейне:

# %%
df['path'] = df['document_id'].str[:24]

# всего 136 дубликатов на трейн и тест
dupls = df[df.duplicated(subset=['path'],keep=False)].sort_values('ctr')
p(dupls.shape)
dupls[:5]
# Out:
# (136, 12)
#  ~
#                    document_id                     title        publish_date  \
# 5693  621a39ba9a79472784f02...  Какие места на Украин... 2022-05-26 10:12:01
# 3213  621a39ba9a79472784f02...  Какие места на Украин... 2022-05-19 09:57:05
# 8380  621a39ba9a79472784f02...  Какие места на Украин... 2022-04-08 11:28:18
# 6247  621a39ba9a79472784f02...  Какие места на Украин... 2022-05-23 09:44:02
# 5908  621a39ba9a79472784f02...  Какие места на Украин... 2022-05-24 10:41:48
#
#                      session authors   ctr                  category  \
# 5693  uzbF3bemQHyNHWFEVMC8bQ      [] 0.000  5409f11ce063da9c8b588a12
# 3213  1UsUPXuzR0CKpx63H0qNOQ      [] 0.000  5409f11ce063da9c8b588a12
# 8380  _hvIU0ZcStKn-km2-kPOmw      [] 0.000  5409f11ce063da9c8b588a12
# 6247  ytL7Y-dhSYm55oHJbra_dg      [] 0.000  5409f11ce063da9c8b588a12
# 5908  347x3OJRQy-WukszVEW-GA      [] 0.000  5409f11ce063da9c8b588a12
#
#                           tags     views  depth  full_reads_percent  \
# 5693  ['5409f191e063daa0f40... 70873.000  1.113              15.581
# 3213  ['5409f191e063daa0f40... 70873.000  1.113              15.581
# 8380  ['5409f191e063daa0f40...       NaN    NaN                 NaN
# 6247  ['5409f191e063daa0f40... 70873.000  1.113              15.581
# 5908  ['5409f191e063daa0f40... 70873.000  1.113              15.581
#
#                           path
# 5693  621a39ba9a79472784f029d4
# 3213  621a39ba9a79472784f029d4
# 8380  621a39ba9a79472784f029d4
# 6247  621a39ba9a79472784f029d4
# 5908  621a39ba9a79472784f029d4

# %%
# дубликаты в трейне
dupls_from_train = dupls[~dupls['views'].isna()].drop_duplicates(subset=['path','ctr']).rename(columns={'document_id':'document_id_train','title':'title_train'}).set_index('path')
p(dupls_from_train.shape)
dupls_from_train[:2]
# Out:
# (41, 11)
#  ~
#                                  document_id_train               title_train  \
# path
# 621a39ba9a79472784f029d4  621a39ba9a79472784f02...  Какие места на Украин...
# 609d11a69a79477cef513697  609d11a69a79477cef513...  Как Запад и Россия по...
#
#                                 publish_date                 session  \
# path
# 621a39ba9a79472784f029d4 2022-05-26 10:12:01  uzbF3bemQHyNHWFEVMC8bQ
# 609d11a69a79477cef513697 2022-04-08 15:53:09  err0XKLMQFGLne6KPYAZEQ
#
#                                            authors   ctr  \
# path
# 621a39ba9a79472784f029d4                        [] 0.000
# 609d11a69a79477cef513697  ['542f8085cbb20f3a1e3... 0.523
#
#                                           category                      tags  \
# path
# 621a39ba9a79472784f029d4  5409f11ce063da9c8b588a12  ['5409f191e063daa0f40...
# 609d11a69a79477cef513697  5409f11ce063da9c8b588a12  ['596cb0199a794738666...
#
#                              views  depth  full_reads_percent
# path
# 621a39ba9a79472784f029d4 70873.000  1.113              15.581
# 609d11a69a79477cef513697  7601.000  1.081              20.563

# %%
dupls_from_train.ctr.nunique()
# Out:
# 41

# %%
# дубликаты в тесте
dupls_from_test = dupls.loc[dupls['views'].isna(),['document_id','path','ctr']].rename(columns={'document_id':'document_id_test'})
p(dupls_from_test.shape)
dupls_from_test[:2]
# Out:
# (37, 3)
#  ~
#               document_id_test                      path   ctr
# 8380  621a39ba9a79472784f02...  621a39ba9a79472784f029d4 0.000
# 7539  621a39ba9a79472784f02...  621a39ba9a79472784f029d4 0.000

# %%
# образцам из теста находим дубликат в трейне
accurate_preds = dupls_from_test.merge(dupls_from_train,left_on='ctr',right_on='ctr')
p(accurate_preds.shape)
accurate_preds[:5]
# Out:
# (32, 13)
#  ~
#            document_id_test                      path   ctr  \
# 0  621a39ba9a79472784f02...  621a39ba9a79472784f029d4 0.000
# 1  621a39ba9a79472784f02...  621a39ba9a79472784f029d4 0.000
# 2  609d11a69a79477cef513...  609d11a69a79477cef513697 0.523
# 3  609d11a69a79477cef513...  609d11a69a79477cef513697 0.599
# 4  6082cca79a79471b74bf1...  6082cca79a79471b74bf1eda 0.709
#
#           document_id_train               title_train        publish_date  \
# 0  621a39ba9a79472784f02...  Какие места на Украин... 2022-05-26 10:12:01
# 1  621a39ba9a79472784f02...  Какие места на Украин... 2022-05-26 10:12:01
# 2  609d11a69a79477cef513...  Как Запад и Россия по... 2022-04-08 15:53:09
# 3  609d11a69a79477cef513...  Как Запад и Россия по... 2022-04-25 16:04:46
# 4  6082cca79a79471b74bf1...  Как менялась ключевая... 2022-04-08 10:31:13
#
#                   session                   authors                  category  \
# 0  uzbF3bemQHyNHWFEVMC8bQ                        []  5409f11ce063da9c8b588a12
# 1  uzbF3bemQHyNHWFEVMC8bQ                        []  5409f11ce063da9c8b588a12
# 2  err0XKLMQFGLne6KPYAZEQ  ['542f8085cbb20f3a1e3...  5409f11ce063da9c8b588a12
# 3  FjtKTKH7S9Oxncnerr-7xA  ['542f8085cbb20f3a1e3...  5409f11ce063da9c8b588a12
# 4  YlQoBTIqQ7qIP9WhN40PPw  ['5b8403979a794771079...  5409f11ce063da9c8b588a18
#
#                        tags     views  depth  full_reads_percent
# 0  ['5409f191e063daa0f40... 70873.000  1.113              15.581
# 1  ['5409f191e063daa0f40... 70873.000  1.113              15.581
# 2  ['596cb0199a794738666...  7601.000  1.081              20.563
# 3  ['596cb0199a794738666... 14217.000  1.060              21.953
# 4  ['5409f174e063daa0f40... 22374.000  1.186              44.610

# %%
cols = ['document_id_test', 'views', 'depth', 'full_reads_percent']
accurate_preds = accurate_preds[cols].sort_values('views')
accurate_preds
# Out:
#             document_id_test       views  depth  full_reads_percent
# 2   609d11a69a79477cef513...    7601.000  1.081              20.563
# 24  627518769a794781b88bc...   12258.000  1.061              19.261
# 12  628dc8fa9a79471596fd5...   12586.000  1.070              47.958
# 3   609d11a69a79477cef513...   14217.000  1.060              21.953
# 21  625568df9a794741e114a...   14931.000  1.067              30.219
# 20  625568df9a794741e114a...   14931.000  1.067              30.219
# 9   625568df9a794741e114a...   17893.000  1.075              34.628
# 8   61f401bf9a79478e78ad4...   20337.000  1.170              19.039
# 4   6082cca79a79471b74bf1...   22374.000  1.186              44.610
# 11  5f92bea39a79475229897...   28497.000  1.164              29.445
# 5   624b49b89a794712b4d8a...   41973.000  1.247              47.976
# 10  620ccb2e9a7947f0fa6e0...   47956.000  1.168              32.653
# 6   5f8017369a794784407eb...   53426.000  1.231              44.076
# 0   621a39ba9a79472784f02...   70873.000  1.113              15.581
# 1   621a39ba9a79472784f02...   70873.000  1.113              15.581
# 7   609d11a69a79477cef513...   74837.000  1.162              21.686
# 31  621a39ba9a79472784f02...  119263.000  1.120              19.698
# 30  621a39ba9a79472784f02...  119263.000  1.120              19.698
# 28  621a39ba9a79472784f02...  120209.000  1.099              14.361
# 29  621a39ba9a79472784f02...  120209.000  1.099              14.361
# 13  5f8017369a794784407eb...  129984.000  1.292              40.749
# 14  5e2fe9459a79479d102ba...  180456.000  1.565              14.232
# 15  5e2fe9459a79479d102ba...  180456.000  1.565              14.232
# 19  621929479a7947d8b8286...  190347.000  1.166              62.360
# 17  5e2fe9459a79479d102ba...  518294.000  1.589              17.699
# 18  5e2fe9459a79479d102ba...  518294.000  1.589              17.699
# 16  5e2fe9459a79479d102ba...  518294.000  1.589              17.699
# 22  621a39ba9a79472784f02...  616365.000  1.240              23.667
# 23  621a39ba9a79472784f02...  616365.000  1.240              23.667
# 25  62074b119a7947b0e49b3... 2554204.000  1.799               4.978
# 26  62074b119a7947b0e49b3... 2554204.000  1.799               4.978
# 27  62074b119a7947b0e49b3... 2554204.000  1.799               4.978

# %%
accurate_preds.to_csv(dir_data+'accurate_preds.csv',index=False)

# %%
# Определим функцию, которая будет в готовом submission корректировать предсказания модели, имеющимися точными предсказаниями
def correct_preds(sub):
    # если модель предсказала отрицательные или очень маленькие значения - это наверняка ошибка - исправляем
    sub.loc[sub['views'] < 500, 'views'] = 500

    all_dupls = pd.read_csv(dir_data+'accurate_preds.csv')

    for i in all_dupls['document_id_test']:
        sub.loc[sub['document_id'] == i, ['views', 'depth', 'full_reads_percent']
                ] = all_dupls.loc[all_dupls['document_id_test'] == i, ['views', 'depth', 'full_reads_percent']].to_numpy().flatten()

    return sub

# %% [markdown]
# ### Обработка данных:
# - label encodings
# - извлечение признаков
# - удаление выбросов
# - очистка и обработка текста

# %%
train = pd.read_csv(dir_data+'train_dataset_train.csv',parse_dates=['publish_date'])
test = pd.read_csv(dir_data+'test_dataset_test.csv',parse_dates=['publish_date'])

encoders = my.load_pickle(dir_data+"encs.pcl")
encoders
# Out:
# {'session_enc': LabelEncoder(),
#  'authors_enc': LabelEncoder(),
#  'tags_enc': LabelEncoder(),
#  'list_authors_enc': LabelEncoder(),
#  'list_tags_enc': LabelEncoder(),
#  'category_enc': LabelEncoder()}

# %%
def number_words(text):
    n = 0
    for word in text.split():
        if len(word)>1:
            n+=1
    return n

def have_upper_words(text):
    for word in text.split():
        if len(word)>1 and word.isupper():
            return 1
    return 0

def number_big_words(text):
    n = 0
    for word in text[1:].split():
        if len(word)>1 and word[0].isupper():
            n+=1
    return n

# %%
def prepro(df):
    df.drop(columns='session',inplace=True)
    
    df['title'] = df['title'].str.split('\n', n=1).str[0]
    df['path'] = df['document_id'].str[:24]

    df['authors'] = df['authors'].apply(str_to_list)
    df['tags'] = df['tags'].apply(str_to_list)

    # столбцы с ff_ - это фичи
    df['ff_num_authors'] = df['authors'].apply(len)
    df['ff_num_tags'] = df['tags'].apply(len)

    encoders = my.load_pickle(dir_data+"encs.pcl")

    # кодируем в строковые последовательности
    df['authors'] = df['authors'].apply(
        encode_list_col, args=(encoders['authors_enc'],'a'))
    df['tags'] = df['tags'].apply(
        encode_list_col, args=(encoders['tags_enc'],'t'))
    

    map_encode = [('category', 'category_enc')]
    my.encode_cols(df, map_encode)

    df['ff_enc_authors'] = encoders["list_authors_enc"].transform(
        df['authors']).astype(np.int32) + 1

    df['ff_month'] = df['publish_date'].dt.month
    df['ff_hour'] = df['publish_date'].dt.hour
    df['ff_day'] = df['publish_date'].dt.day
    df['ff_day_week'] = df['publish_date'].dt.dayofweek
    df['ff_day_year'] = df['publish_date'].dt.dayofyear

    if 'views' in df.columns:
        # if train
        df = df.sort_values('publish_date').copy()

        # удаляем выбросы: статьи со слишком большими просмотрами, имеющими много дубликатов, с некорректным временем
        rules = (~df.title.str.contains('Какие места на Украине взяли')) & (df['publish_date'].dt.year == 2022) & (
            df['publish_date'].dt.dayofyear < 160) & (~df.views.isin([2554204, 518294, 2398050]))

        df = df[rules]
        df.drop_duplicates(subset=['title', 'views'], inplace=True)
        df = df.copy()

        # редкие категории добавляем к близким по смыслу
        df.loc[df.category == 7,'category'] = 1
        df.loc[df.category == 8,'category'] = 3
        df.loc[df.category == 9,'category'] = 6

        # срезаем выбросы в depth и full_reads_percent
        df.loc[df.depth >= 1.5,'depth'] = 1.5
        df.loc[df.full_reads_percent >= 67.,'full_reads_percent'] = 67.

        # делаем столбцы для фолдов на основе категорий
        df['folds_cat'] = df.category
        # df['folds_day'] = df['publish_date'].dt.dayofyear // 20
        df['folds_cat_and_day'] = df.category + (df['publish_date'].dt.dayofyear // 20) * 10
  

    df['ff_have_money'] = df.title.str.contains('[€£₣$₽]').astype(np.int8)
    df['ff_have_number'] = df.title.str.contains('\d').astype(np.int8)
    df['ff_have_quotes'] = df.title.str.contains('«').astype(np.int8)
    df['ff_have_pct'] = df.title.str.contains('%').astype(np.int8)

    df['ff_num_symbols'] = df.title.str.len()
    df['ff_num_words'] = df.title.apply(number_words)
    df['ff_have_upper_words'] = df.title.apply(have_upper_words)
    df['ff_number_big_words'] = df.title.apply(number_big_words)

    df['clean_lem_title'] = text_utils.clean_text(df["title"],do_lemma=True)
    df['clean_no_lem_title'] = text_utils.clean_text(df["title"])

    return df

# %%
train = prepro(train)
test = prepro(test)
train[:2]
# Out:
#                    document_id                     title        publish_date  \
# 4092  61f401bf9a79478e78ad4...  Какие ограничения вво... 2022-01-29 06:00:22
# 5386  5f8017369a794784407eb...  Как в России развивае... 2022-01-29 09:00:53
#
#           authors   ctr  category                      tags   views  depth  \
# 4092       a1 a44 1.284         6  t27 t483 t1575 t6297 ...   20337  1.170
# 5386  a44 a59 a60 2.330         6  t27 t3494 t4860 t6297...  129984  1.292
#
#       full_reads_percent  ... ff_have_money  ff_have_number  ff_have_quotes  \
# 4092              19.039  ...             0               0               1
# 5386              40.749  ...             0               0               0
#
#       ff_have_pct  ff_num_symbols  ff_num_words  ff_have_upper_words  \
# 4092            0              67             8                    0
# 5386            0              52             6                    1
#
#       ff_number_big_words           clean_lem_title        clean_no_lem_title
# 4092                    0  ограничение вводить р...  какие ограничения вво...
# 5386                    3  россия развиваться эп...  россии развивается эп...
#
# [2 rows x 31 columns]

# %%
train.to_parquet(dir_data+'train_v1.p',index=False)
test.to_parquet(dir_data+'test_v1.p',index=False)

# %% [markdown]
# нахождение порядкового номера новости по отношению к другим новостям в течение дня

# %%
# train = pd.read_parquet(dir_data+'train_v1.p')
# test = pd.read_parquet(dir_data+'test_v1.p')

# %%
def get_all_news():
    cols = ['document_id','publish_date','category']
    train = pd.read_csv(dir_data+'train_dataset_train.csv',parse_dates=['publish_date'],usecols=cols)
    test = pd.read_csv(dir_data+'test_dataset_test.csv',parse_dates=['publish_date'],usecols=cols)
    return pd.concat([train,test]).sort_values('publish_date').reset_index(drop=True)
all_news =get_all_news()
p(all_news.shape)
all_news[:3]
# Out:
# (10000, 3)
#  ~
#                 document_id        publish_date                  category
# 0  55c3984d9a79470f2c260... 2017-08-07 13:00:27  5433e5decbb20f277b20eca9
# 1  5a8eb3149a7947e3e34bb... 2018-02-22 14:28:30  5433e5decbb20f277b20eca9
# 2  605321259a7947663a3b6... 2021-04-12 11:01:26  5433e5decbb20f277b20eca9

# %%
all_news['ff_pos_in_day'] = all_news.groupby(all_news['publish_date'].dt.dayofyear)['publish_date'].rank().astype(np.int16)
all_news['ff_pos_in_cat_day'] = all_news.groupby([all_news['publish_date'].dt.dayofyear,'category'])['publish_date'].rank().astype(np.int16)
all_news = all_news.drop(columns=['publish_date','category']).set_index('document_id')
all_news[:3]
# Out:
#                            ff_pos_in_day  ff_pos_in_cat_day
# document_id
# 55c3984d9a79470f2c2604...              1                  1
# 5a8eb3149a7947e3e34bba...              1                  1
# 605321259a7947663a3b6a...              1                  1

# %% [markdown]
# Нахождение количества новостей, вышедших через 30, 60, 120 ... минут после выхода текущей новости, так как из-за них новость опускается в списках на сайте, и получает меньше показов:

# %%
df_counts = get_all_news()
# переводим дату в секунды
df_counts['publish_date'] = df_counts['publish_date'].astype(int) / 10**9

counts_news = []
timings = np.array([30,60,120,300,720,1440]) * 60 # in seconds

for t in df_counts['publish_date']:

    count_one_news = []
    
    for lim in timings:
        ct = ((df_counts['publish_date'] > t) & (df_counts['publish_date'] < (t + lim))).sum()
        count_one_news.append(ct)

    counts_news.append(count_one_news)

counts_news = pd.DataFrame(counts_news,columns=['ff_' + f'count_after_{(lim/60)}' for lim in timings])
p(counts_news.shape)
counts_news[:10]
# Out:
# (10000, 6)
#  ~
#    ff_count_after_30.0  ff_count_after_60.0  ff_count_after_120.0  \
# 0                    0                    0                     0
# 1                    0                    0                     0
# 2                    0                    0                     0
# 3                    0                    0                     0
# 4                    0                    0                     0
# 5                    0                    0                     0
# 6                    0                    0                     0
# 7                    0                    0                     1
# 8                    0                    0                     0
# 9                    0                    0                     0
#
#    ff_count_after_300.0  ff_count_after_720.0  ff_count_after_1440.0
# 0                     0                     0                      0
# 1                     0                     0                      0
# 2                     0                     0                      0
# 3                     0                     0                      0
# 4                     0                     0                      0
# 5                     0                     0                      0
# 6                     0                     0                      0
# 7                     1                     1                      1
# 8                     0                     0                      0
# 9                     1                     1                      1

# %%
counts_news.describe()
# Out:
#        ff_count_after_30.0  ff_count_after_60.0  ff_count_after_120.0  \
# count            10000.000            10000.000             10000.000
# mean                 2.546                5.291                10.780
# std                  1.819                2.959                 5.196
# min                  0.000                0.000                 0.000
# 25%                  1.000                3.000                 7.000
# 50%                  2.000                5.000                10.000
# 75%                  4.000                7.000                14.000
# max                 11.000               18.000                31.000
#
#        ff_count_after_300.0  ff_count_after_720.0  ff_count_after_1440.0
# count             10000.000             10000.000              10000.000
# mean                 26.599                58.370                114.987
# std                  11.437                20.384                 28.627
# min                   0.000                 0.000                  0.000
# 25%                  17.000                42.000                 98.000
# 50%                  25.000                55.500                119.000
# 75%                  35.000                74.000                133.000
# max                  63.000               120.000                179.000

# %% [markdown]
# так как есть дни по которым дано мало новостей, а на самом деле вряд ли были такие дни, когда на сайте было меньше 60 новостей, то присваиваем новостям в такие дни средние значения по датасету:

# %%
mean_counts = counts_news.loc[counts_news['ff_count_after_1440.0']>60].mean().to_list()
mean_counts
# Out:
# [2.573614937251301,
#  5.344250586674829,
#  10.892357922660953,
#  26.879093970003062,
#  59.04132231404959,
#  116.60299969390879]

# %%
counts_news.loc[counts_news['ff_count_after_1440.0']<=60] = mean_counts
counts_news[:3]
# Out:
#    ff_count_after_30.0  ff_count_after_60.0  ff_count_after_120.0  \
# 0                2.574                5.344                10.892
# 1                2.574                5.344                10.892
# 2                2.574                5.344                10.892
#
#    ff_count_after_300.0  ff_count_after_720.0  ff_count_after_1440.0
# 0                26.879                59.041                116.603
# 1                26.879                59.041                116.603
# 2                26.879                59.041                116.603

# %%
counts_news.describe()
# Out:
#        ff_count_after_30.0  ff_count_after_60.0  ff_count_after_120.0  \
# count            10000.000            10000.000             10000.000
# mean                 2.574                5.344                10.892
# std                  1.803                2.926                 5.122
# min                  0.000                0.000                 0.000
# 25%                  1.000                3.000                 7.000
# 50%                  2.000                5.000                10.000
# 75%                  4.000                7.000                14.000
# max                 11.000               18.000                31.000
#
#        ff_count_after_300.0  ff_count_after_720.0  ff_count_after_1440.0
# count             10000.000             10000.000              10000.000
# mean                 26.879                59.041                116.603
# std                  11.235                19.734                 26.104
# min                   5.000                20.000                 61.000
# 25%                  17.000                42.000                102.000
# 50%                  26.000                57.000                119.000
# 75%                  35.000                74.000                133.000
# max                  63.000               120.000                179.000

# %%
df_counts.index, counts_news.index
# Out:
# (RangeIndex(start=0, stop=10000, step=1),
#  RangeIndex(start=0, stop=10000, step=1))

# %%
df_counts[:3]
# Out:
#                 document_id   publish_date                  category
# 0  55c3984d9a79470f2c260... 1502110827.000  5433e5decbb20f277b20eca9
# 1  5a8eb3149a7947e3e34bb... 1519309710.000  5433e5decbb20f277b20eca9
# 2  605321259a7947663a3b6... 1618225286.000  5433e5decbb20f277b20eca9

# %%
df_counts = pd.concat([df_counts[['document_id']],counts_news],axis=1).set_index('document_id')
df_counts[:3]
# Out:
#                            ff_count_after_30.0  ff_count_after_60.0  \
# document_id
# 55c3984d9a79470f2c2604...                2.574                5.344
# 5a8eb3149a7947e3e34bba...                2.574                5.344
# 605321259a7947663a3b6a...                2.574                5.344
#
#                            ff_count_after_120.0  ff_count_after_300.0  \
# document_id
# 55c3984d9a79470f2c2604...                10.892                26.879
# 5a8eb3149a7947e3e34bba...                10.892                26.879
# 605321259a7947663a3b6a...                10.892                26.879
#
#                            ff_count_after_720.0  ff_count_after_1440.0
# document_id
# 55c3984d9a79470f2c2604...                59.041                116.603
# 5a8eb3149a7947e3e34bba...                59.041                116.603
# 605321259a7947663a3b6a...                59.041                116.603

# %%
print((all_news.index == df_counts.index).mean())
all_news = pd.concat([all_news,df_counts],axis=1)
all_news[:2]
# Out:
# 1.0
#                            ff_pos_in_day  ff_pos_in_cat_day  \
# document_id
# 55c3984d9a79470f2c2604...              1                  1
# 5a8eb3149a7947e3e34bba...              1                  1
#
#                            ff_count_after_30.0  ff_count_after_60.0  \
# document_id
# 55c3984d9a79470f2c2604...                2.574                5.344
# 5a8eb3149a7947e3e34bba...                2.574                5.344
#
#                            ff_count_after_120.0  ff_count_after_300.0  \
# document_id
# 55c3984d9a79470f2c2604...                10.892                26.879
# 5a8eb3149a7947e3e34bba...                10.892                26.879
#
#                            ff_count_after_720.0  ff_count_after_1440.0
# document_id
# 55c3984d9a79470f2c2604...                59.041                116.603
# 5a8eb3149a7947e3e34bba...                59.041                116.603

# %%
all_news.describe()
# Out:
#        ff_pos_in_day  ff_pos_in_cat_day  ff_count_after_30.0  \
# count      10000.000          10000.000            10000.000
# mean          59.468             23.757                2.574
# std           37.777             20.992                1.803
# min            1.000              1.000                0.000
# 25%           28.000              6.000                1.000
# 50%           56.000             17.000                2.000
# 75%           88.000             38.000                4.000
# max          171.000            113.000               11.000
#
#        ff_count_after_60.0  ff_count_after_120.0  ff_count_after_300.0  \
# count            10000.000             10000.000             10000.000
# mean                 5.344                10.892                26.879
# std                  2.926                 5.122                11.235
# min                  0.000                 0.000                 5.000
# 25%                  3.000                 7.000                17.000
# 50%                  5.000                10.000                26.000
# 75%                  7.000                14.000                35.000
# max                 18.000                31.000                63.000
#
#        ff_count_after_720.0  ff_count_after_1440.0
# count             10000.000              10000.000
# mean                 59.041                116.603
# std                  19.734                 26.104
# min                  20.000                 61.000
# 25%                  42.000                102.000
# 50%                  57.000                119.000
# 75%                  74.000                133.000
# max                 120.000                179.000

# %%
train = train.merge(all_news,left_on='document_id',right_index=True).sort_values('publish_date')
p(train.shape)
train[:2]
# Out:
# (6937, 39)
#  ~
#                    document_id                     title        publish_date  \
# 4092  61f401bf9a79478e78ad4...  Какие ограничения вво... 2022-01-29 06:00:22
# 5386  5f8017369a794784407eb...  Как в России развивае... 2022-01-29 09:00:53
#
#           authors   ctr  category                      tags   views  depth  \
# 4092       a1 a44 1.284         6  t27 t483 t1575 t6297 ...   20337  1.170
# 5386  a44 a59 a60 2.330         6  t27 t3494 t4860 t6297...  129984  1.292
#
#       full_reads_percent  ...           clean_lem_title  \
# 4092              19.039  ...  ограничение вводить р...
# 5386              40.749  ...  россия развиваться эп...
#
#             clean_no_lem_title  ff_pos_in_day  ff_pos_in_cat_day  \
# 4092  какие ограничения вво...              1                  1
# 5386  россии развивается эп...              2                  2
#
#       ff_count_after_30.0  ff_count_after_60.0  ff_count_after_120.0  \
# 4092                2.574                5.344                10.892
# 5386                2.574                5.344                10.892
#
#       ff_count_after_300.0  ff_count_after_720.0  ff_count_after_1440.0
# 4092                26.879                59.041                116.603
# 5386                26.879                59.041                116.603
#
# [2 rows x 39 columns]

# %%
temp = all_news.reindex(test['document_id']).reset_index(drop=True)
test = pd.concat([test,temp],axis=1)
p(test.shape)
test[:2]
# Out:
# (3000, 34)
#  ~
#                 document_id                     title        publish_date  \
# 0  61f9569a9a794794245a8...  «Крайне провокационна... 2022-02-01 17:02:44
# 1  628c22b89a79470e553f5...  Власти Херсонской обл... 2022-05-24 00:50:55
#
#    authors   ctr  category                      tags  \
# 0  a100000 0.000         1  t36 t39 t116 t5455 t5524
# 1  a100000 1.598         1     t452 t869 t1589 t6449
#
#                        path  ff_num_authors  ff_num_tags  ...  \
# 0  61f9569a9a794794245a82ab               0            5  ...
# 1  628c22b89a79470e553f594b               0            4  ...
#
#             clean_lem_title        clean_no_lem_title  ff_pos_in_day  \
# 0  крайне провокационный...  крайне провокационная...            115
# 1  власть херсонский обл...  власти херсонской обл...              2
#
#    ff_pos_in_cat_day  ff_count_after_30.0  ff_count_after_60.0  \
# 0                 48                2.000                8.000
# 1                  2                1.000                1.000
#
#    ff_count_after_120.0  ff_count_after_300.0  ff_count_after_720.0  \
# 0                13.000                26.000                54.000
# 1                 5.000                15.000                75.000
#
#    ff_count_after_1440.0
# 0                153.000
# 1                143.000
#
# [2 rows x 34 columns]

# %%
train.to_parquet(dir_data+'train_v2.p',index=False)
test.to_parquet(dir_data+'test_v2.p',index=False)

# %% [markdown]
# Добавление данных, полученных парсингом страниц новостей
#
# Дальше файл pages_info.p или берется готовый из папки data репозитория, или предварительно парсится в другом ноутбуке.

# %%
train = pd.read_parquet(dir_data+'train_v2.p')
test = pd.read_parquet(dir_data+'test_v2.p')

pages_info = pd.read_parquet(dir_data+'pages_info.p')
pages_info[:3]
# Out:
#                           ww_number_links  ww_have_overview  ww_have_ticker  \
# path
# 623e3fe49a7947150616c930                6                 1               0
# 61fb1d219a79473037413488                3                 0               0
# 628c71589a794723047f6d37                0                 1               0
#
#                           ww_len_overview  ww_num_symbols  \
# path
# 623e3fe49a7947150616c930              126            2133
# 61fb1d219a79473037413488                0            1303
# 628c71589a794723047f6d37              151            2657
#
#                           ww_num_symbols_until_item  ww_pro_in_article  \
# path
# 623e3fe49a7947150616c930                       956                   1
# 61fb1d219a79473037413488                       600                   1
# 628c71589a794723047f6d37                      2657                   0
#
#                           ww_num_inline_items  ww_have_iframe  ww_number_ps  \
# path
# 623e3fe49a7947150616c930                    1               0            10
# 61fb1d219a79473037413488                    1               0             8
# 628c71589a794723047f6d37                    0               0             7
#
#                           ww_num_symbols_until_pro  ww_have_video_recommend  \
# path
# 623e3fe49a7947150616c930                      1534                        0
# 61fb1d219a79473037413488                      1303                        0
# 628c71589a794723047f6d37                      2657                        0
#
#                           ww_have_video_in  ww_num_symbols_until_video_in  \
# path
# 623e3fe49a7947150616c930                 1                       873
# 61fb1d219a79473037413488                 1                       515
# 628c71589a794723047f6d37                 1                       844
#
#                           ww_have_image                      text  ww_feat1  \
# path
# 623e3fe49a7947150616c930              1  информация издание са...     0.448
# 61fb1d219a79473037413488              1  рефрижераторный судно...     0.460
# 628c71589a794723047f6d37              1  защита алексей наваль...     1.000
#
#                           ww_feat2  ww_feat3
# path
# 623e3fe49a7947150616c930     0.719     0.409
# 61fb1d219a79473037413488     0.999     0.395
# 628c71589a794723047f6d37     1.000     0.318

# %%
train = train.merge(pages_info,left_on='path',right_index=True).sort_values('publish_date')
p(train.shape)
train[:2]
# Out:
# (6937, 58)
#  ~
#                 document_id                     title        publish_date  \
# 0  61f401bf9a79478e78ad4...  Какие ограничения вво... 2022-01-29 06:00:22
# 1  5f8017369a794784407eb...  Как в России развивае... 2022-01-29 09:00:53
#
#        authors   ctr  category                      tags   views  depth  \
# 0       a1 a44 1.284         6  t27 t483 t1575 t6297 ...   20337  1.170
# 1  a44 a59 a60 2.330         6  t27 t3494 t4860 t6297...  129984  1.292
#
#    full_reads_percent  ... ww_number_ps  ww_num_symbols_until_pro  \
# 0              19.039  ...           36                      2127
# 1              40.749  ...            2                       452
#
#    ww_have_video_recommend  ww_have_video_in  ww_num_symbols_until_video_in  \
# 0                        0                 1                      1349
# 1                        0                 0                     10000
#
#    ww_have_image                      text  ww_feat1  ww_feat2  ww_feat3
# 0              1  заболеваемость covid ...     0.408     0.298     0.189
# 1              0  число выявить сутки с...     0.998     0.998    22.075
#
# [2 rows x 58 columns]

# %%
temp = pages_info.reindex(test['path']).reset_index(drop=True)
test = pd.concat([test,temp],axis=1)
p(test.shape)
test[:2]
# Out:
# (3000, 53)
#  ~
#                 document_id                     title        publish_date  \
# 0  61f9569a9a794794245a8...  «Крайне провокационна... 2022-02-01 17:02:44
# 1  628c22b89a79470e553f5...  Власти Херсонской обл... 2022-05-24 00:50:55
#
#    authors   ctr  category                      tags  \
# 0  a100000 0.000         1  t36 t39 t116 t5455 t5524
# 1  a100000 1.598         1     t452 t869 t1589 t6449
#
#                        path  ff_num_authors  ff_num_tags  ...  ww_number_ps  \
# 0  61f9569a9a794794245a82ab               0            5  ...             3
# 1  628c22b89a79470e553f594b               0            4  ...             9
#
#    ww_num_symbols_until_pro  ww_have_video_recommend  ww_have_video_in  \
# 0                       876                        0                 0
# 1                      2317                        0                 1
#
#    ww_num_symbols_until_video_in  ww_have_image                      text  \
# 0                     10000                   0  постпред россия оон в...
# 1                      1380                   1  русский стать основны...
#
#    ww_feat1  ww_feat2  ww_feat3
# 0     0.999     0.999    11.403
# 1     0.456     0.765     0.456
#
# [2 rows x 53 columns]

# %%
train.to_parquet(dir_data+'train.p',index=False)
test.to_parquet(dir_data+'test.p',index=False)
